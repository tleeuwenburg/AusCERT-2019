# %%
# !ps -axf
# Out:
#   UID   PID  PPID   C STIME   TTY           TIME CMD
#     0     1     0   0 15May19 ??        11:43.06 /sbin/launchd
#     0    57     1   0 15May19 ??         0:26.13 /usr/sbin/syslogd
#     0    58     1   0 15May19 ??         0:21.16 /usr/libexec/UserEventAgent (System)
#     0    61     1   0 15May19 ??         0:12.53 /System/Library/PrivateFrameworks/Uninstall.framework/Resources/uninstalld
#     0    62     1   0 15May19 ??         2:51.51 /usr/libexec/kextd
#     0    63     1   0 15May19 ??        15:15.18 /System/Library/Frameworks/CoreServices.framework/Versions/A/Frameworks/FSEvents.framework/Versions/A/Support/fseventsd
#    55    68     1   0 15May19 ??         0:09.84 /System/Library/CoreServices/appleeventsd --server
#     0    69     1   0 15May19 ??         5:50.32 /usr/sbin/systemstats --daemon
#     0    71     1   0 15May19 ??         1:07.54 /usr/libexec/configd
# ...

# %%
# !rm test.txt

# %%
import os
import time
for i in range(5):
    # !ps -axf >> test.txt
    time.sleep(5)

# %%
# !ls
# Out:
# Cross-platform process.ipynb
# Dumping process information with ps (clunky but quick).ipynb
# test.txt

# %%
# !cat 'test.txt'
# Out:
#   UID   PID  PPID   C STIME   TTY           TIME CMD
#     0     1     0   0 15May19 ??        11:43.60 /sbin/launchd
#     0    57     1   0 15May19 ??         0:26.18 /usr/sbin/syslogd
#     0    58     1   0 15May19 ??         0:21.21 /usr/libexec/UserEventAgent (System)
#     0    61     1   0 15May19 ??         0:12.54 /System/Library/PrivateFrameworks/Uninstall.framework/Resources/uninstalld
#     0    62     1   0 15May19 ??         2:52.58 /usr/libexec/kextd
#     0    63     1   0 15May19 ??        15:15.47 /System/Library/Frameworks/CoreServices.framework/Versions/A/Frameworks/FSEvents.framework/Versions/A/Support/fseventsd
#    55    68     1   0 15May19 ??         0:09.85 /System/Library/CoreServices/appleeventsd --server
#     0    69     1   0 15May19 ??         5:50.35 /usr/sbin/systemstats --daemon
#     0    71     1   0 15May19 ??         1:07.88 /usr/libexec/configd
# ...

# %%
first = open('test.txt').readlines()

# %%
first[0].strip()
# Out:
# 'UID   PID  PPID   C STIME   TTY           TIME CMD'

# %%
first[1].strip()
# Out:
# '0     1     0   0 15May19 ??        11:43.60 /sbin/launchd'
